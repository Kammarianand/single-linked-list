# %% [markdown]
# <a href="https://colab.research.google.com/github/Kammarianand/single-linked-list/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
img = [[0,0,0],
       [50,50,50],
       [100,100,100],
       [255,255,255]]

plt.imshow(img,cmap='gray')

# %%
img = [[[255,0,0],[100,0,0],[50,0,0]],
       [[0,255,0],[0,100,0],[0,50,0]],
       [[0,0,255],[0,0,100],[0,0,50]]]

plt.imshow(img)

# %%
img = [[[255,0,0],[100,0,0],[50,0,0]],
       [[0,255,0],[0,100,0],[0,50,0]],
       [[0,0,255],[0,0,100],[0,0,50]]]

plt.imshow(img)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create 3x3 grid
x, y = np.meshgrid(np.arange(3), np.arange(3))

# Set colors based on the given array
colors = [
    (1, 0, 0),  # Red
    (0, 1, 0),  # Green
    (0, 0, 1),  # Blue
    (1, 1, 0),  # Yellow
    (1, 0.5, 0),  # Orange
    (1, 1, 1)  # White
]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot each square with the respective color
for i in range(3):
    for j in range(3):
        ax.bar3d(i, j, 0, 1, 1, 0.01, color=colors[i+j])

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create 3x3 grid
x, y = np.meshgrid(np.arange(3), np.arange(3))

# Set colors based on the given array
colors = [
    (1, 0, 0),  # Red
    (0, 1, 0),  # Green
    (0, 0, 1),  # Blue
    (1, 1, 0),  # Yellow
    (1, 0.5, 0),  # Orange
    (1, 1, 1)  # White
]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot each square with the respective color
for i in range(3):
    for j in range(3):
        ax.bar3d(i, j, 0, 1, 1, 0.01, color=colors[i+j], edgecolor='black')

# Remove axis and grid lines
ax.axis('off')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create 3x3 grid
x, y = np.meshgrid(np.arange(3), np.arange(3))

# Set colors based on the given array
colors = [
    (1, 0, 0),  # Red
    (0, 1, 0),  # Green
    (0, 0, 1),  # Blue
    (1, 1, 0),  # Yellow
    (1, 0.5, 0),  # Orange
    (1, 1, 1)  # White
]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot each square with the respective color
for i in range(3):
    for j in range(3):
        ax.bar3d(i, j, 0, 1, 1, 0.01, color=colors[i + j], edgecolor='black')

# Set aspect and perspective to make it look like blocks
ax.set_box_aspect([1,1,0.5]) # aspect ratio
ax.dist = 12  # perspective

ax.axis('off')  # Remove axis
plt.show()
# Out:
# <ipython-input-14-f53b8e3c47c3>:28: MatplotlibDeprecationWarning: The dist attribute was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.dist = 12  # perspective

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create 3x3 grid
x, y = np.meshgrid(np.arange(3), np.arange(3))

# Set colors based on the given array
colors = [
    (1, 0, 0),  # Red
    (0, 1, 0),  # Green
    (0, 0, 1),  # Blue
    (1, 1, 0),  # Yellow
    (1, 0.5, 0),  # Orange
    (1, 1, 1)  # White
]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot each square with the respective color
for i in range(3):
    for j in range(3):
        ax.bar3d(i, j, 0, 1, 1, 0.01, color=colors[i+j], edgecolor='black')

# Remove axis and grid lines
ax.axis('off')

# Rotate the plot on the z-axis
ax.view_init(elev=20., azim=30)

plt.show()

# %%
import time
import matplotlib.pyplot as plt

# Sorting algorithms
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]

def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        L = arr[:mid]
        R = arr[mid:]

        merge_sort(L)
        merge_sort(R)

        i = j = k = 0

        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1

        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1

        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1

def partition(arr, low, high):
    i = low - 1
    pivot = arr[high]

    for j in range(low, high):
        if arr[j] < pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]

    arr[i+1], arr[high] = arr[high], arr[i+1]
    return i+1

def quick_sort(arr, low, high):
    if low < high:
        pi = partition(arr, low, high)
        quick_sort(arr, low, pi-1)
        quick_sort(arr, pi+1, high)

# Searching algorithm
def binary_search(arr, x):
    low = 0
    high = len(arr) - 1
    while low <= high:
        mid = (low + high) // 2
        if arr[mid] < x:
            low = mid + 1
        elif arr[mid] > x:
            high = mid - 1
        else:
            return mid
    return -1

# Function to measure time taken for sorting and searching
def measure_time_complexity(arr, algorithm, target=None):
    start_time = time.time()
    if target is not None:
        algorithm(arr, target)
    else:
        algorithm(arr)
    end_time = time.time()
    return end_time - start_time

# Generate random data to sort and search
array_size = 1000
data = list(range(array_size))
random_data = data[:]
import random
random.shuffle(random_data)

# Measure the time taken for each algorithm
sorting_algorithms = [bubble_sort, merge_sort, quick_sort]
searching_algorithm = binary_search

timings = []
for algorithm in sorting_algorithms:
    timings.append(measure_time_complexity(random_data[:], algorithm))
timings.append(measure_time_complexity(data[:], searching_algorithm, 500))

# Plot the time complexity
algorithm_names = ["Bubble Sort", "Merge Sort", "Quick Sort", "Binary Search"]
plt.bar(algorithm_names, timings)
plt.xlabel('Algorithm')
plt.ylabel('Time Taken (seconds)')
plt.title('Time Complexity of Sorting and Searching Algorithms')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-04b03ec3b273> in <cell line: 96>()
#      95 timings = []
#      96 for algorithm in sorting_algorithms:
# ---> 97     timings.append(measure_time_complexity(random_data[:], algorithm))
#      98 timings.append(measure_time_complexity(data[:], searching_algorithm, 500))
#      99
#
# <ipython-input-17-04b03ec3b273> in measure_time_complexity(arr, algorithm, target)
#      78         algorithm(arr, target)
#      79     else:
# ---> 80         algorithm(arr)
#      81     end_time = time.time()
#      82     return end_time - start_time
#
# TypeError: quick_sort() missing 2 required positional arguments: 'low' and 'high'

# %%
# Python code to create a simple HTML page
html = '''
<!DOCTYPE html>
<html>
<head>
    <title>Sample HTML Page</title>
</head>
<body>
    <header>
        <h1>Welcome to My Web Page</h1>
        <nav>
            <ul>
                <li><a href="#">Home</a></li>
                <li><a href="#">About</a></li>
                <li><a href="#">Contact</a></li>
            </ul>
        </nav>
    </header>
    <main>
        <h2>About Me</h2>
        <p>This is a sample HTML page created using Python.</p>
    </main>
    <footer>
        <p>&copy; 2023 Sample HTML Page</p>
    </footer>
</body>
</html>
'''

# Write the HTML to a file
with open('sample.html', 'w') as file:
    file.write(html)
    print("HTML file created successfully")
# Out:
# HTML file created successfully
